# %% [markdown]
# Nama : Ema Rusma Wati

# %% [markdown]
# Nim : 1911102441041

# %%
import numpy as np

a = np.array([1, 2, 3, 4 ,5])

print(a.shape)
print(a.dtype)
# Out:
# (5,)
# int64

# %%
import matplotlib.pyplot as plt
x = np.random.normal(3.0, 2.0, 1000)

plt.hist(x, 100)
plt.show()

# %%
from google.colab import files
import cv2

file = files.upload()
# Out:
#      <input type="file" id="files-a8ed201f-04b4-49c0-ba31-c7296f97f7fb" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a8ed201f-04b4-49c0-ba31-c7296f97f7fb">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving logo umkt1.png to logo umkt1.png

# %%
from google.colab.patches import cv2_imshow
img = cv2.imread('logo umkt1.png')

cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=469x469 at 0x7F8154945E10>

# %%
fig = plt.figure()
fig.add_subplot(121)

plt.imshow(img)

fig.add_subplot(122)

img2 = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.imshow(img2)

plt.show()

# %%
b, g, r  = cv2.split(img)


print('dimensi gambar:')
print(img.shape)
# Out:
# dimensi gambar:
# (469, 469, 3)

# %%
img3 = img
for i, row in enumerate(img):
  for j, pixel in enumerate(img):
    means = (b[i][j]+g[i][j]+r[i][j])/3 
    img3[i][j] = [means, means, means]

cv2_imshow(img3)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: RuntimeWarning: overflow encountered in ubyte_scalars
#   after removing the cwd from sys.path.
# <PIL.Image.Image image mode=RGB size=469x469 at 0x7F8149900410>

# %%
from google.colab.patches import cv2_imshow
import cv2

img = cv2.imread('logo umkt1.png')
flip = cv2.flip(img, 1)
cv2_imshow(flip)
img1 = cv2.imread('logo umkt1.png')
cv2_imshow(img1)
# Out:
# <PIL.Image.Image image mode=RGB size=469x469 at 0x7F81499001D0>
# <PIL.Image.Image image mode=RGB size=469x469 at 0x7F8149972B90>

# %%
from google.colab.patches import cv2_imshow
import cv2

img2 = cv2.imread('logo umkt1.png')
imggray = cv2.imread('logo umkt1.png', 0)
cv2_imshow(imggray)
img3 = cv2.imread('logo umkt1.png')
cv2_imshow(img3)
# Out:
# <PIL.Image.Image image mode=L size=469x469 at 0x7F8149952F10>
# <PIL.Image.Image image mode=RGB size=469x469 at 0x7F8149952A50>
